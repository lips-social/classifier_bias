# %%
import boto3
import logging
import requests
import pprint
import logging
from rekognition_image_detection import RekognitionImage
from rekognition_objects import show_bounding_boxes, show_polygons

# %%
bucket_name = "reliabl-image-labeling-demo"

logging.basicConfig(level=logging.INFO, format="%(levelname)s: %(message)s")
rekognition_client = boto3.client("rekognition")
# Out:
# INFO: Found credentials in shared credentials file: ~/.aws/credentials

# %%
#############
# start model

# adapted from https://github.com/awsdocs/amazon-rekognition-custom-labels-developer-guide/blob/master/LICENSE-SAMPLECODE

import boto3

def start_model(project_arn, model_arn, version_name, min_inference_units):

    client=boto3.client('rekognition')

    try:
        # Start the model
        print('Starting model: ' + model_arn)
        response=client.start_project_version(ProjectVersionArn=model_arn, MinInferenceUnits=min_inference_units)
        # Wait for the model to be in the running state
        project_version_running_waiter = client.get_waiter('project_version_running')
        project_version_running_waiter.wait(ProjectArn=project_arn, VersionNames=[version_name])

        #Get the running status
        describe_response=client.describe_project_versions(ProjectArn=project_arn,
            VersionNames=[version_name])
        for model in describe_response['ProjectVersionDescriptions']:
            print("Status: " + model['Status'])
            print("Message: " + model['StatusMessage']) 
    except Exception as e:
        print(e)
        
    print('Done...')

project_arn='arn:aws:rekognition:us-west-2:643735647393:project/reliabl-labeling-demo/1735924965950'
model_arn='arn:aws:rekognition:us-west-2:643735647393:project/reliabl-labeling-demo/version/reliabl-labeling-demo.2025-01-10T21.13.06/1736561586865'
min_inference_units=1 
version_name='reliabl-labeling-demo.2025-01-10T21.13.06'
start_model(project_arn, model_arn, version_name, min_inference_units)
# Out:
# Starting model: arn:aws:rekognition:us-west-2:643735647393:project/reliabl-labeling-demo/version/reliabl-labeling-demo.2025-01-10T21.13.06/1736561586865
# Status: RUNNING
# Message: The model is running.
# Done...

# %%
#adapted from https://github.com/awsdocs/amazon-rekognition-custom-labels-developer-guide/blob/master/LICENSE-SAMPLECODE

import boto3
import io
from PIL import Image, ImageDraw, ExifTags, ImageColor, ImageFont

def display_image(bucket,photo,response):
    # Load image from S3 bucket
    s3_connection = boto3.resource('s3')

    s3_object = s3_connection.Object(bucket,photo)
    s3_response = s3_object.get()

    stream = io.BytesIO(s3_response['Body'].read())
    image=Image.open(stream)

    # Ready image to draw bounding boxes on it.
    imgWidth, imgHeight = image.size
    draw = ImageDraw.Draw(image)

    # calculate and display bounding boxes for each detected custom label
    print('Detected custom labels for ' + photo)
    for customLabel in response['CustomLabels']:
        print('Label ' + str(customLabel['Name']))
        print('Confidence ' + str(customLabel['Confidence']))
        if 'Geometry' in customLabel:
            box = customLabel['Geometry']['BoundingBox']
            left = imgWidth * box['Left']
            top = imgHeight * box['Top']
            width = imgWidth * box['Width']
            height = imgHeight * box['Height']

            fnt = ImageFont.truetype('/Library/Fonts/Arial.ttf', 50)
            draw.text((left,top), customLabel['Name'], fill='#00d400', font=fnt)

            print('Left: ' + '{0:.0f}'.format(left))
            print('Top: ' + '{0:.0f}'.format(top))
            print('Label Width: ' + "{0:.0f}".format(width))
            print('Label Height: ' + "{0:.0f}".format(height))

            points = (
                (left,top),
                (left + width, top),
                (left + width, top + height),
                (left , top + height),
                (left, top))
            draw.line(points, fill='#00d400', width=5)

    image.show()

def show_custom_labels(model,bucket,photo, min_confidence):
    client=boto3.client('rekognition')

    #Call DetectCustomLabels
    response = client.detect_custom_labels(Image={'S3Object': {'Bucket': bucket, 'Name': photo}},
        MinConfidence=min_confidence,
        ProjectVersionArn=model)

    # For object detection use case, uncomment below code to display image.
    # display_image(bucket,photo,response)

    return response['CustomLabels']

# %% [markdown]
# ## gather test set for binary moderation task (suggestive / non_suggestive)

# %%
import pandas as pd

manifest_file = "./manifest/suggestive-non-suggestive_test_2025-01-10T21:09:29.103691.csv"
test_set = pd.read_csv(manifest_file, names=["filename", "label"])
test_set
# Out:
#                                              filename           label
# 0          BreastExam/dreamstimemaximum_250259473.jpg  non_suggestive
# 1          BreastExam/dreamstimemaximum_207123274.jpg  non_suggestive
# 2          BreastExam/dreamstimemaximum_133939417.jpg  non_suggestive
# 3           BreastExam/dreamstimemaximum_96797189.jpg  non_suggestive
# 4           BreastExam/dreamstimemaximum_94323393.jpg  non_suggestive
# 5           BreastExam/dreamstimemaximum_94306606.jpg  non_suggestive
# 6           BreastExam/dreamstimemaximum_59736182.jpg  non_suggestive
# 7   Menstruation/What_are_heavy_periods_Kk8hREp.wi...  non_suggestive
# 8   ReproductiveHealth/dreamstimemaximum_45400686.jpg  non_suggestive
# 9          Suggestive/dreamstimemaximum_194102913.jpg      suggestive
# 10         Suggestive/dreamstimemaximum_140720311.jpg      suggestive
# 11         Suggestive/dreamstimemaximum_113797033.jpg      suggestive
# 12          Suggestive/dreamstimemaximum_96835820.jpg      suggestive
# 13  WomensHealthGeneral/dreamstimemaximum_33143927...  non_suggestive
# 14  WomensHealthGeneral/dreamstimemaximum_16547398...  non_suggestive
# 15  WomensHealthGeneral/dreamstimemaximum_14899981...  non_suggestive
# 16  WomensHealthGeneral/dreamstimemaximum_14803528...  non_suggestive
# 17  WomensHealthGeneral/dreamstimemaximum_14715254...  non_suggestive
# 18  WomensHealthGeneral/dreamstimemaximum_12107076...  non_suggestive
# 19  WomensHealthGeneral/dreamstimemaximum_11568306...  non_suggestive
# 20  WomensHealthGeneral/dreamstimemaximum_97457146...  non_suggestive
# 21  WomensHealthGeneral/dreamstimemaximum_20682371...  non_suggestive
# 22  PregnantNonSuggestive/tracy-truhan-U5Jc1Cfz228...  non_suggestive
# 23  PregnantNonSuggestive/tony-luginsland-rqCP3-1A...  non_suggestive
# 24  PregnantNonSuggestive/toa-heftiba-cHmKxSne48k-...  non_suggestive
# 25  PregnantNonSuggestive/thiago-ferreira-HwFm1MNK...  non_suggestive
# 26  PregnantNonSuggestive/sierra-koder-18fVqLZ7Ghw...  non_suggestive
# 27  PregnantNonSuggestive/rene-porter-LagGwBSSElY-...  non_suggestive
# 28  PregnantNonSuggestive/raspopova-marina-DoBuAVC...  non_suggestive
# 29  PregnantNonSuggestive/max-bohme-d4BvB5Yu5gg-un...  non_suggestive
# 30  PregnantNonSuggestive/max-bohme-23QjOMIdLM4-un...  non_suggestive
# 31  PregnantNonSuggestive/max-bohme-3j3of277RT0-un...  non_suggestive
# 32  PregnantNonSuggestive/leticia-pelissari-cWrQHd...  non_suggestive
# 33  PregnantNonSuggestive/jernej-graj-WmsnqCK9Jzg-...  non_suggestive
# 34  PregnantNonSuggestive/ignacio-campo-FKOjXAbJWl...  non_suggestive
# 35  PregnantNonSuggestive/dreamstimemaximum_283575...  non_suggestive
# 36  PregnantNonSuggestive/dreamstimemaximum_281496...  non_suggestive
# 37  PregnantNonSuggestive/dreamstimemaximum_191989...  non_suggestive
# 38  PregnantNonSuggestive/dreamstimemaximum_175332...  non_suggestive
# 39  PregnantNonSuggestive/dreamstimemaximum_170223...  non_suggestive
# 40  PregnantNonSuggestive/dreamstimemaximum_366402...  non_suggestive
# 41  PregnantNonSuggestive/dragos-gontariu-bqG4F5RB...  non_suggestive
# 42  PregnantNonSuggestive/anna-deli-X-TcNKHso4s-un...  non_suggestive
# 43  PregnantNonSuggestive/anna-deli-aV1yYGcK1jU-un...  non_suggestive
# 44  PregnantNonSuggestive/andre-adjahoe-tqunk3qB_y...  non_suggestive
# 45  PregnantSuggestive/Pregnancy_Pictures_140807_0...      suggestive
# 46                    PregnantSuggestive/images-2.jpg      suggestive
# 47  PregnantSuggestive/hotmilk-warrior-nursing-bra...      suggestive
# 48  PregnantSuggestive/dreamstimemaximum_253857570...      suggestive
# 49  PregnantSuggestive/dreamstimemaximum_250938011...      suggestive
# 50  PregnantSuggestive/dreamstimemaximum_245024234...      suggestive
# 51  PregnantSuggestive/dreamstimemaximum_245024206...      suggestive
# 52  PregnantSuggestive/dreamstimemaximum_237018648...      suggestive
# 53  PregnantSuggestive/dreamstimemaximum_216642668...      suggestive
# 54  PregnantSuggestive/dreamstimemaximum_145713360...      suggestive
# 55      PregnantSuggestive/dreamstime_m_328775612.jpg      suggestive
# 56      PregnantSuggestive/dreamstime_m_179640101.jpg      suggestive
# 57      PregnantSuggestive/dreamstime_m_146191781.jpg      suggestive
# 58      PregnantSuggestive/dreamstime_m_143437542.jpg      suggestive

# %% [markdown]
# ## label test set images using custom model

# %%
# loop through all eval files and write results
model='arn:aws:rekognition:us-west-2:643735647393:project/reliabl-labeling-demo/version/reliabl-labeling-demo.2025-01-10T21.13.06/1736561586865'
min_confidence=50

eval_labels = []
for image_name, label in test_set.itertuples(index=False):
    print(f"image, label: {image_name}, {label}")

    photo=f'resized/{image_name}'

    labels = show_custom_labels(model, bucket_name, photo, min_confidence)
    eval_labels.append(labels)
    print("Custom labels detected: " + str(labels))
# Out:
# image, label: BreastExam/dreamstimemaximum_250259473.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 92.67500305175781}]
# image, label: BreastExam/dreamstimemaximum_207123274.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 96.83799743652344}]
# image, label: BreastExam/dreamstimemaximum_133939417.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 98.40599822998047}]
# image, label: BreastExam/dreamstimemaximum_96797189.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 78.85700225830078}]
# image, label: BreastExam/dreamstimemaximum_94323393.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 87.16799926757812}]
# image, label: BreastExam/dreamstimemaximum_94306606.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 98.98600006103516}]
# image, label: BreastExam/dreamstimemaximum_59736182.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.06999969482422}]
# image, label: Menstruation/What_are_heavy_periods_Kk8hREp.width-960.png, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 98.94599914550781}]
# image, label: ReproductiveHealth/dreamstimemaximum_45400686.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 93.45899963378906}]
# image, label: Suggestive/dreamstimemaximum_194102913.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 90.71599578857422}]
# image, label: Suggestive/dreamstimemaximum_140720311.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 75.3030014038086}]
# image, label: Suggestive/dreamstimemaximum_113797033.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 92.46800231933594}]
# image, label: Suggestive/dreamstimemaximum_96835820.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.25}]
# image, label: WomensHealthGeneral/dreamstimemaximum_331439279.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 97.61199951171875}]
# image, label: WomensHealthGeneral/dreamstimemaximum_165473986.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 97.8010025024414}]
# image, label: WomensHealthGeneral/dreamstimemaximum_148999817.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.83499908447266}]
# image, label: WomensHealthGeneral/dreamstimemaximum_148035283.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 94.64300537109375}]
# image, label: WomensHealthGeneral/dreamstimemaximum_147152548.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.72000122070312}]
# image, label: WomensHealthGeneral/dreamstimemaximum_121070767.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 93.47599792480469}]
# image, label: WomensHealthGeneral/dreamstimemaximum_115683068.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 88.71099853515625}]
# image, label: WomensHealthGeneral/dreamstimemaximum_97457146.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 85.12699890136719}]
# image, label: WomensHealthGeneral/dreamstimemaximum_20682371.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 83.28400421142578}]
# image, label: PregnantNonSuggestive/tracy-truhan-U5Jc1Cfz228-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 98.85200500488281}]
# image, label: PregnantNonSuggestive/tony-luginsland-rqCP3-1Apas-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 79.25199890136719}]
# image, label: PregnantNonSuggestive/toa-heftiba-cHmKxSne48k-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 89.41799926757812}]
# image, label: PregnantNonSuggestive/thiago-ferreira-HwFm1MNKzXg-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 94.63199615478516}]
# image, label: PregnantNonSuggestive/sierra-koder-18fVqLZ7Ghw-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.89299774169922}]
# image, label: PregnantNonSuggestive/rene-porter-LagGwBSSElY-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 93.46699523925781}]
# image, label: PregnantNonSuggestive/raspopova-marina-DoBuAVCg_Do-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 97.64900207519531}]
# image, label: PregnantNonSuggestive/max-bohme-d4BvB5Yu5gg-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.32099914550781}]
# image, label: PregnantNonSuggestive/max-bohme-23QjOMIdLM4-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 96.61299896240234}]
# image, label: PregnantNonSuggestive/max-bohme-3j3of277RT0-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 98.04900360107422}]
# image, label: PregnantNonSuggestive/leticia-pelissari-cWrQHdPANnc-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.99700164794922}]
# image, label: PregnantNonSuggestive/jernej-graj-WmsnqCK9Jzg-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.06600189208984}]
# image, label: PregnantNonSuggestive/ignacio-campo-FKOjXAbJWlw-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 95.82499694824219}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_283575797.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 87.38899993896484}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_281496398.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 75.4679946899414}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_191989514.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 97.91699981689453}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_175332402.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 83.18299865722656}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_170223200.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 97.73999786376953}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_36640291.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.16500091552734}]
# image, label: PregnantNonSuggestive/dragos-gontariu-bqG4F5RBqoQ-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 99.9800033569336}]
# image, label: PregnantNonSuggestive/anna-deli-X-TcNKHso4s-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 97.17900085449219}]
# image, label: PregnantNonSuggestive/anna-deli-aV1yYGcK1jU-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 68.62000274658203}]
# image, label: PregnantNonSuggestive/andre-adjahoe-tqunk3qB_yU-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 97.66899871826172}]
# image, label: PregnantSuggestive/Pregnancy_Pictures_140807_003.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 96.2760009765625}]
# image, label: PregnantSuggestive/images-2.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 63.090003967285156}]
# image, label: PregnantSuggestive/hotmilk-warrior-nursing-bra-jan-2024.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 52.926998138427734}]
# image, label: PregnantSuggestive/dreamstimemaximum_253857570.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 52.79600143432617}]
# image, label: PregnantSuggestive/dreamstimemaximum_250938011.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 84.25899505615234}]
# image, label: PregnantSuggestive/dreamstimemaximum_245024234.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 50.362998962402344}]
# image, label: PregnantSuggestive/dreamstimemaximum_245024206.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 65.31400299072266}]
# image, label: PregnantSuggestive/dreamstimemaximum_237018648.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 60.650997161865234}]
# image, label: PregnantSuggestive/dreamstimemaximum_216642668.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 67.40299987792969}]
# image, label: PregnantSuggestive/dreamstimemaximum_145713360.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 71.81900024414062}]
# image, label: PregnantSuggestive/dreamstime_m_328775612.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 63.06599807739258}]
# image, label: PregnantSuggestive/dreamstime_m_179640101.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 50.95099639892578}]
# image, label: PregnantSuggestive/dreamstime_m_146191781.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 55.72999572753906}]
# image, label: PregnantSuggestive/dreamstime_m_143437542.jpg, suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 75.41799926757812}]

# %%
# make sure evaluation labels populated correctly 
eval_labels[0]
# Out:
# [{'Name': 'non_suggestive', 'Confidence': 92.67500305175781}]

# %% [markdown]
# ### assess accuracy (TP/FP/TN/FN) of custom moderation labels

# %%
test_set.loc[:, "custom_model_response"] = eval_labels

test_set.loc[:, "custom_model_label"] = [[xi["Name"] for xi in x] for x in eval_labels]
test_set.loc[:, "custom_model_confidence"] = [[xi["Confidence"] for xi in x] for x in eval_labels]

def r(true_label, inferred_label):
    if true_label == "non_suggestive" and inferred_label == "non_suggestive":
        return "TN"
    if true_label == "suggestive" and inferred_label == "non_suggestive":
        return "FN"
    if true_label == "non_suggestive" and inferred_label == "suggestive":
        return "FP"
    if true_label == "suggestive" and inferred_label == "suggestive":
        return "TP"

test_set.loc[:, "custom_model_quality"] = test_set.apply(lambda x: r(x["label"], x["custom_model_label"][0]), axis=1)

# %%
# merge in aws label results
moderation_label_file = "./labeling_results/moderation_labels.tsv"
aws_mod_results = pd.read_csv(moderation_label_file, names=["image", "aws_labels", "error"], sep="\t")
aws_mod_results.loc[:, "image_name"] = aws_mod_results["image"].apply(lambda x: x[len("resized/"):])
test_set = test_set.merge(aws_mod_results[["image_name", "aws_labels"]], how="left", left_on="filename", right_on="image_name")

test_set.to_csv("./evaluation_results/aws_custom_model_results.csv")

# %%
test_set.head()
# Out:
#                                      filename           label  \
# 0  BreastExam/dreamstimemaximum_250259473.jpg  non_suggestive
# 1  BreastExam/dreamstimemaximum_207123274.jpg  non_suggestive
# 2  BreastExam/dreamstimemaximum_133939417.jpg  non_suggestive
# 3   BreastExam/dreamstimemaximum_96797189.jpg  non_suggestive
# 4   BreastExam/dreamstimemaximum_94323393.jpg  non_suggestive
#
#                                custom_model_response custom_model_label  \
# 0  [{'Name': 'non_suggestive', 'Confidence': 92.6...   [non_suggestive]
# 1  [{'Name': 'non_suggestive', 'Confidence': 96.8...   [non_suggestive]
# 2  [{'Name': 'non_suggestive', 'Confidence': 98.4...   [non_suggestive]
# 3  [{'Name': 'non_suggestive', 'Confidence': 78.8...   [non_suggestive]
# 4  [{'Name': 'non_suggestive', 'Confidence': 87.1...   [non_suggestive]
#
#   custom_model_confidence custom_model_quality  \
# 0     [92.67500305175781]                   TN
# 1     [96.83799743652344]                   TN
# 2     [98.40599822998047]                   TN
# 3     [78.85700225830078]                   TN
# 4     [87.16799926757812]                   TN
#
#                                    image_name aws_labels
# 0  BreastExam/dreamstimemaximum_250259473.jpg         []
# 1  BreastExam/dreamstimemaximum_207123274.jpg         []
# 2  BreastExam/dreamstimemaximum_133939417.jpg         []
# 3   BreastExam/dreamstimemaximum_96797189.jpg         []
# 4   BreastExam/dreamstimemaximum_94323393.jpg         []

# %%
aws_mod_results.head()
# Out:
#                                                image  \
# 0                                  resized/.DS_Store
# 1  resized/BreastExam/dreamstimemaximum_103407046...
# 2  resized/BreastExam/dreamstimemaximum_103761283...
# 3  resized/BreastExam/dreamstimemaximum_118626718...
# 4  resized/BreastExam/dreamstimemaximum_133939417...
#
#                                           aws_labels  \
# 0                                                 []
# 1  [{name": "Emaciated Bodies", "parent_name": "D...
# 2  [{name": "Swimwear or Underwear", "parent_name...
# 3  [{name": "Non-Explicit Nudity of Intimate part...
# 4                                                 []
#
#                                                error  \
# 0  An error occurred (InvalidImageFormatException...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    image_name
# 0                                   .DS_Store
# 1  BreastExam/dreamstimemaximum_103407046.jpg
# 2  BreastExam/dreamstimemaximum_103761283.jpg
# 3  BreastExam/dreamstimemaximum_118626718.jpg
# 4  BreastExam/dreamstimemaximum_133939417.jpg

# %% [markdown]
# ## apply labels for custom classification model for womens health categories (not assessed for accuracy here)

# %%
# loop through all eval files and write results
model='arn:aws:rekognition:us-west-2:643735647393:project/reliabl-labeling-demo-all-labels/version/reliabl-labeling-demo-all-labels.2025-01-10T21.12.46/1736561566379'
min_confidence=50

custom_labels = []
image_names = []
for image_name, label in test_set.itertuples(index=False):
    print(f"image, label: {image_name}, {label}")

    photo=f'resized/{image_name}'

    labels = show_custom_labels(model,bucket_name,photo, min_confidence)
    custom_labels.append(labels)
    image_names.append(image_name)

    print("Custom labels detected: " + str(labels))
# Out:
# image, label: BreastExam/dreamstimemaximum_250259473.jpg, non_suggestive
# Custom labels detected: [{'Name': 'health_context', 'Confidence': 73.44999694824219}, {'Name': 'breast_exam', 'Confidence': 65.76499938964844}, {'Name': 'pregnancy_visible', 'Confidence': 63.551002502441406}, {'Name': 'underwear_visible', 'Confidence': 62.84199905395508}, {'Name': 'non_suggestive', 'Confidence': 60.000003814697266}, {'Name': 'pregant_belly_exposed', 'Confidence': 60.000003814697266}, {'Name': 'suggestive', 'Confidence': 58.34000015258789}]
# image, label: BreastExam/dreamstimemaximum_207123274.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 91.05500030517578}, {'Name': 'pregant_belly_exposed', 'Confidence': 85.73500061035156}, {'Name': 'health_context', 'Confidence': 77.1259994506836}, {'Name': 'pregnancy_visible', 'Confidence': 71.91799926757812}, {'Name': 'breast_exam', 'Confidence': 60.000003814697266}]
# image, label: BreastExam/dreamstimemaximum_133939417.jpg, non_suggestive
# Custom labels detected: [{'Name': 'breast_exam', 'Confidence': 97.37699890136719}, {'Name': 'non_suggestive', 'Confidence': 97.3479995727539}, {'Name': 'underwear_visible', 'Confidence': 92.29199981689453}, {'Name': 'health_context', 'Confidence': 91.49299621582031}]
# image, label: BreastExam/dreamstimemaximum_96797189.jpg, non_suggestive
# Custom labels detected: [{'Name': 'topless_breasts', 'Confidence': 91.65499877929688}, {'Name': 'non_suggestive', 'Confidence': 85.47000122070312}, {'Name': 'health_context', 'Confidence': 83.59500122070312}, {'Name': 'breast_exam', 'Confidence': 66.7020034790039}, {'Name': 'pregnancy_visible', 'Confidence': 53.52899932861328}, {'Name': 'nipple_exposed', 'Confidence': 50.17499923706055}]
# image, label: BreastExam/dreamstimemaximum_94323393.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 91.63899993896484}, {'Name': 'health_context', 'Confidence': 90.87999725341797}, {'Name': 'breast_exam', 'Confidence': 83.06000518798828}, {'Name': 'topless_breasts', 'Confidence': 60.000003814697266}, {'Name': 'nipple_exposed', 'Confidence': 56.457000732421875}]
# image, label: BreastExam/dreamstimemaximum_94306606.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 87.9749984741211}, {'Name': 'breast_exam', 'Confidence': 73.9990005493164}, {'Name': 'health_context', 'Confidence': 71.41899871826172}, {'Name': 'nipple_exposed', 'Confidence': 60.000003814697266}]
# image, label: BreastExam/dreamstimemaximum_59736182.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 95.36299896240234}, {'Name': 'health_context', 'Confidence': 85.0260009765625}, {'Name': 'nipple_exposed', 'Confidence': 74.21399688720703}, {'Name': 'breast_exam', 'Confidence': 64.70000457763672}, {'Name': 'underwear_visible', 'Confidence': 60.000003814697266}]
# image, label: Menstruation/What_are_heavy_periods_Kk8hREp.width-960.png, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 80.04399871826172}, {'Name': 'health_context', 'Confidence': 69.2179946899414}]
# image, label: ReproductiveHealth/dreamstimemaximum_45400686.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 98.5260009765625}, {'Name': 'health_context', 'Confidence': 81.27400207519531}]
# image, label: Suggestive/dreamstimemaximum_194102913.jpg, suggestive
# Custom labels detected: [{'Name': 'health_context', 'Confidence': 87.18000030517578}, {'Name': 'non_suggestive', 'Confidence': 77.58300018310547}, {'Name': 'lingerie ', 'Confidence': 71.47700500488281}, {'Name': 'swimsuit', 'Confidence': 60.000003814697266}, {'Name': 'underwear_visible', 'Confidence': 54.000003814697266}]
# image, label: Suggestive/dreamstimemaximum_140720311.jpg, suggestive
# Custom labels detected: [{'Name': 'slightly_suggestive', 'Confidence': 91.65499877929688}, {'Name': 'lingerie ', 'Confidence': 91.48500061035156}, {'Name': 'pregnancy_visible', 'Confidence': 75.30400085449219}, {'Name': 'suggestive', 'Confidence': 68.53700256347656}, {'Name': 'photography', 'Confidence': 60.000003814697266}, {'Name': 'artistic_context', 'Confidence': 60.000003814697266}]
# image, label: Suggestive/dreamstimemaximum_113797033.jpg, suggestive
# Custom labels detected: [{'Name': 'photography', 'Confidence': 88.63300323486328}, {'Name': 'artistic_context', 'Confidence': 88.63300323486328}, {'Name': 'pregnancy_visible', 'Confidence': 64.59500122070312}, {'Name': 'suggestive', 'Confidence': 62.19000244140625}, {'Name': 'lingerie ', 'Confidence': 60.000003814697266}, {'Name': 'slightly_suggestive', 'Confidence': 60.000003814697266}, {'Name': 'non_suggestive', 'Confidence': 55.48999786376953}, {'Name': 'underwear_visible', 'Confidence': 52.86300277709961}, {'Name': 'health_context', 'Confidence': 51.432003021240234}]
# image, label: Suggestive/dreamstimemaximum_96835820.jpg, suggestive
# Custom labels detected: [{'Name': 'swimsuit', 'Confidence': 80.25299835205078}, {'Name': 'pregnancy_visible', 'Confidence': 70.54399871826172}, {'Name': 'non_suggestive', 'Confidence': 64.92000579833984}, {'Name': 'suggestive', 'Confidence': 55.058998107910156}]
# image, label: WomensHealthGeneral/dreamstimemaximum_331439279.jpg, non_suggestive
# Custom labels detected: [{'Name': 'health_context', 'Confidence': 82.34400177001953}, {'Name': 'non_suggestive', 'Confidence': 80.43399810791016}]
# image, label: WomensHealthGeneral/dreamstimemaximum_165473986.jpg, non_suggestive
# Custom labels detected: [{'Name': 'swimsuit', 'Confidence': 92.6760025024414}, {'Name': 'non_suggestive', 'Confidence': 92.08399963378906}, {'Name': 'slightly_suggestive', 'Confidence': 56.47800064086914}, {'Name': 'lingerie ', 'Confidence': 56.1150016784668}, {'Name': 'health_context', 'Confidence': 55.34600067138672}, {'Name': 'artistic_context', 'Confidence': 54.43099594116211}, {'Name': 'photography', 'Confidence': 54.43099594116211}, {'Name': 'pregnancy_visible', 'Confidence': 53.7339973449707}]
# image, label: WomensHealthGeneral/dreamstimemaximum_148999817.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 95.74099731445312}, {'Name': 'health_context', 'Confidence': 93.92300415039062}]
# image, label: WomensHealthGeneral/dreamstimemaximum_148035283.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 92.9229965209961}, {'Name': 'health_context', 'Confidence': 80.38500213623047}, {'Name': 'swimsuit', 'Confidence': 51.1150016784668}]
# image, label: WomensHealthGeneral/dreamstimemaximum_147152548.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 96.23400115966797}, {'Name': 'health_context', 'Confidence': 91.36399841308594}]
# image, label: WomensHealthGeneral/dreamstimemaximum_121070767.jpg, non_suggestive
# Custom labels detected: [{'Name': 'underwear_visible', 'Confidence': 70.38499450683594}, {'Name': 'non_suggestive', 'Confidence': 65.06199645996094}, {'Name': 'health_context', 'Confidence': 64.24400329589844}, {'Name': 'pregnancy_visible', 'Confidence': 61.926002502441406}, {'Name': 'pregant_belly_exposed', 'Confidence': 55.935001373291016}, {'Name': 'suggestive', 'Confidence': 54.959999084472656}]
# image, label: WomensHealthGeneral/dreamstimemaximum_115683068.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 89.92900085449219}, {'Name': 'health_context', 'Confidence': 80.0530014038086}, {'Name': 'breast_exam', 'Confidence': 71.23500061035156}, {'Name': 'pregnancy_visible', 'Confidence': 61.317996978759766}]
# image, label: WomensHealthGeneral/dreamstimemaximum_97457146.jpg, non_suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 72.8699951171875}, {'Name': 'health_context', 'Confidence': 61.96600341796875}, {'Name': 'underwear_visible', 'Confidence': 56.73999786376953}, {'Name': 'pregnancy_visible', 'Confidence': 56.18299865722656}, {'Name': 'pregant_belly_exposed', 'Confidence': 52.454002380371094}]
# image, label: WomensHealthGeneral/dreamstimemaximum_20682371.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 88.46700286865234}, {'Name': 'health_context', 'Confidence': 67.2969970703125}]
# image, label: PregnantNonSuggestive/tracy-truhan-U5Jc1Cfz228-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 90.44599914550781}, {'Name': 'non_suggestive', 'Confidence': 66.51800537109375}, {'Name': 'suggestive', 'Confidence': 53.939002990722656}]
# image, label: PregnantNonSuggestive/tony-luginsland-rqCP3-1Apas-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 95.12300109863281}, {'Name': 'non_suggestive', 'Confidence': 71.73400115966797}, {'Name': 'artistic_context', 'Confidence': 55.65500259399414}, {'Name': 'photography', 'Confidence': 55.65500259399414}, {'Name': 'slightly_suggestive', 'Confidence': 54.26700210571289}, {'Name': 'lingerie ', 'Confidence': 53.76700210571289}, {'Name': 'swimsuit', 'Confidence': 52.39899826049805}, {'Name': 'suggestive', 'Confidence': 50.051998138427734}]
# image, label: PregnantNonSuggestive/toa-heftiba-cHmKxSne48k-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 90.625}, {'Name': 'non_suggestive', 'Confidence': 76.54899597167969}]
# image, label: PregnantNonSuggestive/thiago-ferreira-HwFm1MNKzXg-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 86.11199951171875}, {'Name': 'artistic_context', 'Confidence': 72.52200317382812}, {'Name': 'photography', 'Confidence': 72.5199966430664}, {'Name': 'pregnancy_visible', 'Confidence': 60.000003814697266}, {'Name': 'lingerie ', 'Confidence': 55.402000427246094}, {'Name': 'swimsuit', 'Confidence': 54.272003173828125}]
# image, label: PregnantNonSuggestive/sierra-koder-18fVqLZ7Ghw-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 89.0260009765625}, {'Name': 'pregnancy_visible', 'Confidence': 69.92499542236328}]
# image, label: PregnantNonSuggestive/rene-porter-LagGwBSSElY-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 89.51200103759766}, {'Name': 'pregnancy_visible', 'Confidence': 89.26699829101562}, {'Name': 'nipple_exposed', 'Confidence': 58.04100036621094}]
# image, label: PregnantNonSuggestive/raspopova-marina-DoBuAVCg_Do-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'nipple_exposed', 'Confidence': 87.56700134277344}, {'Name': 'health_context', 'Confidence': 80.77899932861328}, {'Name': 'non_suggestive', 'Confidence': 79.9729995727539}]
# image, label: PregnantNonSuggestive/max-bohme-d4BvB5Yu5gg-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 96.04499816894531}, {'Name': 'health_context', 'Confidence': 78.25}, {'Name': 'nipple_exposed', 'Confidence': 61.46699905395508}, {'Name': 'pregnancy_visible', 'Confidence': 60.02000045776367}, {'Name': 'breast_exam', 'Confidence': 52.08100128173828}]
# image, label: PregnantNonSuggestive/max-bohme-23QjOMIdLM4-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 83.50199890136719}, {'Name': 'non_suggestive', 'Confidence': 61.45199966430664}, {'Name': 'suggestive', 'Confidence': 57.39500045776367}]
# image, label: PregnantNonSuggestive/max-bohme-3j3of277RT0-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 89.16400146484375}, {'Name': 'pregnancy_visible', 'Confidence': 73.15599822998047}, {'Name': 'health_context', 'Confidence': 59.33799743652344}]
# image, label: PregnantNonSuggestive/leticia-pelissari-cWrQHdPANnc-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 88.69100189208984}, {'Name': 'pregnancy_visible', 'Confidence': 63.086997985839844}, {'Name': 'nipple_exposed', 'Confidence': 60.21000289916992}, {'Name': 'health_context', 'Confidence': 52.14899826049805}]
# image, label: PregnantNonSuggestive/jernej-graj-WmsnqCK9Jzg-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 85.29399871826172}, {'Name': 'suggestive', 'Confidence': 70.77100372314453}, {'Name': 'swimsuit', 'Confidence': 50.086997985839844}]
# image, label: PregnantNonSuggestive/ignacio-campo-FKOjXAbJWlw-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 85.79800415039062}, {'Name': 'pregnancy_visible', 'Confidence': 65.49100494384766}, {'Name': 'health_context', 'Confidence': 53.3489990234375}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_283575797.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 88.56199645996094}, {'Name': 'pregnancy_visible', 'Confidence': 69.04299926757812}, {'Name': 'health_context', 'Confidence': 60.000003814697266}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_281496398.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 82.81700134277344}, {'Name': 'non_suggestive', 'Confidence': 70.50599670410156}, {'Name': 'health_context', 'Confidence': 52.249996185302734}, {'Name': 'suggestive', 'Confidence': 51.00299835205078}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_191989514.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 70.39399719238281}, {'Name': 'health_context', 'Confidence': 68.82099914550781}, {'Name': 'non_suggestive', 'Confidence': 67.77999877929688}, {'Name': 'suggestive', 'Confidence': 53.03300094604492}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_175332402.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 79.4010009765625}, {'Name': 'non_suggestive', 'Confidence': 68.12699890136719}, {'Name': 'suggestive', 'Confidence': 52.78099822998047}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_170223200.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 76.97599792480469}, {'Name': 'pregnancy_visible', 'Confidence': 62.542999267578125}, {'Name': 'health_context', 'Confidence': 56.018001556396484}]
# image, label: PregnantNonSuggestive/dreamstimemaximum_36640291.jpg, non_suggestive
# Custom labels detected: [{'Name': 'non_suggestive', 'Confidence': 88.88199615478516}, {'Name': 'health_context', 'Confidence': 78.91699981689453}, {'Name': 'underwear_visible', 'Confidence': 54.84300231933594}, {'Name': 'breast_exam', 'Confidence': 53.97200012207031}]
# image, label: PregnantNonSuggestive/dragos-gontariu-bqG4F5RBqoQ-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'nipple_exposed', 'Confidence': 92.0}, {'Name': 'non_suggestive', 'Confidence': 77.68599700927734}, {'Name': 'health_context', 'Confidence': 68.3479995727539}, {'Name': 'topless_breasts', 'Confidence': 52.527000427246094}]
# image, label: PregnantNonSuggestive/anna-deli-X-TcNKHso4s-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 70.53700256347656}, {'Name': 'non_suggestive', 'Confidence': 62.90299987792969}, {'Name': 'suggestive', 'Confidence': 56.432003021240234}, {'Name': 'artistic_context', 'Confidence': 54.33300018310547}, {'Name': 'photography', 'Confidence': 54.33300018310547}, {'Name': 'lingerie ', 'Confidence': 52.06800079345703}]
# image, label: PregnantNonSuggestive/anna-deli-aV1yYGcK1jU-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 89.30599975585938}, {'Name': 'suggestive', 'Confidence': 66.54999542236328}, {'Name': 'non_suggestive', 'Confidence': 51.0160026550293}]
# image, label: PregnantNonSuggestive/andre-adjahoe-tqunk3qB_yU-unsplash.jpg, non_suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 89.03700256347656}, {'Name': 'non_suggestive', 'Confidence': 80.18299865722656}]
# image, label: PregnantSuggestive/Pregnancy_Pictures_140807_003.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 77.35900115966797}, {'Name': 'pregnancy_visible', 'Confidence': 65.2719955444336}, {'Name': 'artistic_context', 'Confidence': 58.659000396728516}, {'Name': 'photography', 'Confidence': 58.659000396728516}, {'Name': 'underwear_visible', 'Confidence': 52.047000885009766}]
# image, label: PregnantSuggestive/images-2.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 68.42500305175781}, {'Name': 'suggestive', 'Confidence': 60.000003814697266}, {'Name': 'non_suggestive', 'Confidence': 57.63099670410156}]
# image, label: PregnantSuggestive/hotmilk-warrior-nursing-bra-jan-2024.jpg, suggestive
# Custom labels detected: [{'Name': 'pregant_belly_exposed', 'Confidence': 90.87299346923828}, {'Name': 'artistic_context', 'Confidence': 90.54000091552734}, {'Name': 'photography', 'Confidence': 90.54000091552734}, {'Name': 'lingerie ', 'Confidence': 85.61900329589844}, {'Name': 'underwear_visible', 'Confidence': 85.43399810791016}, {'Name': 'suggestive', 'Confidence': 64.92000579833984}, {'Name': 'health_context', 'Confidence': 60.211997985839844}, {'Name': 'pregnancy_visible', 'Confidence': 60.154998779296875}, {'Name': 'slightly_suggestive', 'Confidence': 56.709999084472656}, {'Name': 'non_suggestive', 'Confidence': 52.7239990234375}]
# image, label: PregnantSuggestive/dreamstimemaximum_253857570.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 89.1780014038086}, {'Name': 'suggestive', 'Confidence': 88.58399963378906}]
# image, label: PregnantSuggestive/dreamstimemaximum_250938011.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 94.71700286865234}, {'Name': 'suggestive', 'Confidence': 86.81099700927734}]
# image, label: PregnantSuggestive/dreamstimemaximum_245024234.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 92.71199798583984}, {'Name': 'pregnancy_visible', 'Confidence': 84.36100006103516}, {'Name': 'swimsuit', 'Confidence': 63.904998779296875}]
# image, label: PregnantSuggestive/dreamstimemaximum_245024206.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 87.46499633789062}, {'Name': 'suggestive', 'Confidence': 81.45500183105469}, {'Name': 'lingerie ', 'Confidence': 55.284000396728516}, {'Name': 'slightly_suggestive', 'Confidence': 55.220001220703125}, {'Name': 'artistic_context', 'Confidence': 52.253997802734375}, {'Name': 'photography', 'Confidence': 52.253997802734375}]
# image, label: PregnantSuggestive/dreamstimemaximum_237018648.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 78.58499908447266}, {'Name': 'non_suggestive', 'Confidence': 63.43899917602539}, {'Name': 'artistic_context', 'Confidence': 56.28600311279297}, {'Name': 'photography', 'Confidence': 56.28600311279297}, {'Name': 'suggestive', 'Confidence': 56.07100296020508}]
# image, label: PregnantSuggestive/dreamstimemaximum_216642668.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 88.1510009765625}, {'Name': 'pregnancy_visible', 'Confidence': 87.36399841308594}]
# image, label: PregnantSuggestive/dreamstimemaximum_145713360.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 93.02899932861328}, {'Name': 'pregnancy_visible', 'Confidence': 81.81600189208984}]
# image, label: PregnantSuggestive/dreamstime_m_328775612.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 90.09600067138672}, {'Name': 'suggestive', 'Confidence': 86.9000015258789}]
# image, label: PregnantSuggestive/dreamstime_m_179640101.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 94.60800170898438}, {'Name': 'suggestive', 'Confidence': 81.24099731445312}]
# image, label: PregnantSuggestive/dreamstime_m_146191781.jpg, suggestive
# Custom labels detected: [{'Name': 'suggestive', 'Confidence': 83.42000579833984}, {'Name': 'underwear_visible', 'Confidence': 52.644996643066406}, {'Name': 'pregnancy_visible', 'Confidence': 51.36399841308594}, {'Name': 'swimsuit', 'Confidence': 50.64799880981445}]
# image, label: PregnantSuggestive/dreamstime_m_143437542.jpg, suggestive
# Custom labels detected: [{'Name': 'pregnancy_visible', 'Confidence': 74.78099822998047}, {'Name': 'suggestive', 'Confidence': 62.51199722290039}, {'Name': 'non_suggestive', 'Confidence': 55.16999816894531}, {'Name': 'swimsuit', 'Confidence': 52.59700012207031}]

# %%
# save all custom labels to tsv
import json
with open("./labeling_results/aws_custom_labels.tsv", "w") as f:
    for image, labels in zip(image_names, custom_labels):
        f.write(image + "\t" + json.dumps(labels) + "\n")

# %%
# merge these labels into the custom model results
results_file = pd.read_csv("./evaluation_results/aws_custom_model_results.csv")
custom_label_df = pd.read_csv("./labeling_results/aws_custom_labels.tsv", delimiter="\t", names=["image_name", "aws_custom_labels"])


results_file = results_file.merge(custom_label_df, left_on="filename", right_on="image_name", how="left")

# results_file.to_csv('./evaluation_results/final_results.csv')

# %%
# merge in google moderation results
import pandas as pd
google_mod_results = pd.read_csv("./labeling_results/google_moderation_labels.tsv", delimiter="\t", names=["image_name", "google_moderation_labels"])

results_file = results_file.merge(google_mod_results, left_on="filename", right_on="image_name", how="left")

results_file.to_csv('./evaluation_results/final_results.csv')
